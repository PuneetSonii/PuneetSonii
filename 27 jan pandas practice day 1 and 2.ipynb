# %%
import pandas as pd

# %% [markdown]
# #### Read CSV Files
# A simple way to store big data sets is to use CSV files (comma separated files).
#
# CSV files contains plain text and is a well know format that can be read by everyone including Pandas.
#
# In our examples we will be using a CSV file called 'data.csv'.

# %%
data = pd.read_csv('C:/work/addresses.csv')

# %%
print(data)
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### # What is a DataFrame?
# DataFrame is a 2-dimensional labeled data structure with columns of potentially different types. You can think of it like a spreadsheet or SQL table, or a dict of Series objects. It is generally the most commonly used pandas object. Like Series, DataFrame accepts many different kinds of input:(https://pandas.pydata.org/docs/user_guide/dsintro.html#:~:text=DataFrame%20is%20a%202%2Ddimensional,most%20commonly%20used%20pandas%20object.)

# %%
data.head()
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
# 3   4            4       24 Second Avenue       NaN     San Mateo
# 4   5            5       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US
# 3             CA       94401      US
# 4             CA       94401      US

# %%
data
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
data.head(6) #so if i am giving 6,it will give first 6 line
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
# 3   4            4       24 Second Avenue       NaN     San Mateo
# 4   5            5       24 Second Avenue       NaN     San Mateo
# 5   6            6      800 Middle Avenue       NaN    Menlo Park
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US
# 3             CA       94401      US
# 4             CA       94401      US
# 5             CA  94025-9881      US

# %%
data.tail() #tail will give last 5 lines by default
# Out:
#     id  location_id                   address_1  address_2  \
# 16  17           17     409 South Spruce Avenue        NaN
# 17  18           18            114 Fifth Avenue        NaN
# 18  19           19         19 West 39th Avenue        NaN
# 19  20           21          123 El Camino Real        NaN
# 20  21           22  2013 Avenue of the fellows  Suite 100
#
#                    city state_province postal_code country
# 16  South San Francisco             CA       94080      US
# 17         Redwood City             CA       94063      US
# 18            San Mateo             CA       94403      US
# 19              Belmont             CA       94002      US
# 20        San Francisco             CA       94103      US

# %%
data.tail(7) # i try to read last 7 lines
# Out:
#     id  location_id                   address_1  address_2  \
# 14  15           15        1500 Valencia Street        NaN
# 15  16           16         1161 South Bernardo        NaN
# 16  17           17     409 South Spruce Avenue        NaN
# 17  18           18            114 Fifth Avenue        NaN
# 18  19           19         19 West 39th Avenue        NaN
# 19  20           21          123 El Camino Real        NaN
# 20  21           22  2013 Avenue of the fellows  Suite 100
#
#                    city state_province postal_code country
# 14        San Francisco             CA       94110      US
# 15            Sunnyvale             CA       94087      US
# 16  South San Francisco             CA       94080      US
# 17         Redwood City             CA       94063      US
# 18            San Mateo             CA       94403      US
# 19              Belmont             CA       94002      US
# 20        San Francisco             CA       94103      US

# %%
data.columns # list of all column name
# Out:
# Index(['id', 'location_id', 'address_1', 'address_2', 'city', 'state_province',
#        'postal_code', 'country'],
#       dtype='object')

# %%
list(data.columns) # try to view in last format
# Out:
# ['id',
#  'location_id',
#  'address_1',
#  'address_2',
#  'city',
#  'state_province',
#  'postal_code',
#  'country']

# %%
data.head(3) # first 3
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US

# %%
data[['id','address_1']] #using this code we can take just 2  rows likeas,id and address_1
# Out:
#     id                   address_1
# 0    1       2600 Middlefield Road
# 1    2            24 Second Avenue
# 2    3            24 Second Avenue
# 3    4            24 Second Avenue
# 4    5            24 Second Avenue
# 5    6           800 Middle Avenue
# 6    7              500 Arbor Road
# 7    8           800 Middle Avenue
# 8    9       2510 Middlefield Road
# 9   10       1044 Middlefield Road
# 10  11         2140 Euclid Avenue.
# 11  12       1044 Middlefield Road
# 12  13         399 Marine Parkway.
# 13  14          660 Veterans Blvd.
# 14  15        1500 Valencia Street
# 15  16         1161 South Bernardo
# 16  17     409 South Spruce Avenue
# 17  18            114 Fifth Avenue
# 18  19         19 West 39th Avenue
# 19  20          123 El Camino Real
# 20  21  2013 Avenue of the fellows

# %%
data[['city','location_id']]
# Out:
#                    city  location_id
# 0          Redwood City            1
# 1             San Mateo            2
# 2             San Mateo            3
# 3             San Mateo            4
# 4             San Mateo            5
# 5            Menlo Park            6
# 6            Menlo Park            7
# 7            Menlo Park            8
# 8          Redwood City            9
# 9          Redwood City           10
# 10         Redwood City           11
# 11         Redwood City           12
# 12         Redwood City           13
# 13         Redwood City           14
# 14        San Francisco           15
# 15            Sunnyvale           16
# 16  South San Francisco           17
# 17         Redwood City           18
# 18            San Mateo           19
# 19              Belmont           21
# 20        San Francisco           22

# %%
data[['state_province']] # here we try to fetch one single column list
# Out:
#    state_province
# 0              CA
# 1              CA
# 2              CA
# 3              CA
# 4              CA
# 5              CA
# 6              CA
# 7              CA
# 8              CA
# 9              CA
# 10             CA
# 11             CA
# 12             CA
# 13             CA
# 14             CA
# 15             CA
# 16             CA
# 17             CA
# 18             CA
# 19             CA
# 20             CA

# %%
data['state_province']
# Out:
# 0     CA
# 1     CA
# 2     CA
# 3     CA
# 4     CA
# 5     CA
# 6     CA
# 7     CA
# 8     CA
# 9     CA
# 10    CA
# 11    CA
# 12    CA
# 13    CA
# 14    CA
# 15    CA
# 16    CA
# 17    CA
# 18    CA
# 19    CA
# 20    CA
# Name: state_province, dtype: object

# %%
type(data['state_province']) # cheking type
# Out:
# pandas.core.series.Series

# %%
type(data[['state_province']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# > Series is a type of list in pandas which can take integer values, string values, double values and more. But in Pandas Series we return an object in the form of list, having index starting from 0 to n, Where n is the length of values in series. Later in this article, we will discuss dataframes in pandas, but we first need to understand the main difference between Series and Dataframe. Series can only contain single list with index, whereas dataframe can be made of more than one series or we can say that a dataframe is a collection of series that can be used to analyse the data. (https://www.geeksforgeeks.org/creating-a-dataframe-from-pandas-series/)

# %% [markdown]
# > example:

# %%
type(data['state_province']) # cheking type
# Out:
# pandas.core.series.Series

# %%
data['state_province']
# Out:
# 0     CA
# 1     CA
# 2     CA
# 3     CA
# 4     CA
# 5     CA
# 6     CA
# 7     CA
# 8     CA
# 9     CA
# 10    CA
# 11    CA
# 12    CA
# 13    CA
# 14    CA
# 15    CA
# 16    CA
# 17    CA
# 18    CA
# 19    CA
# 20    CA
# Name: state_province, dtype: object

# %% [markdown]
# > https://www.pythonpool.com/oserror-errno22-invalid-argument-solved/

# %% [markdown]
# > here we have to install excel pip

# %% [markdown]
# > https://www.youtube.com/watch?v=xjD3NX_xJWE

# %%
file = pd.read_excel("C:/work/airline.xls")

# %%
data = pd.read_excel("C:/work/airline.xls")

# %%
print(data)
# Out:
#     YEAR      Y      W       R      L      K
# 0   1948  1.214  0.243  0.1454  1.415  0.612
# 1   1949  1.354  0.260  0.2181  1.384  0.559
# 2   1950  1.569  0.278  0.3157  1.388  0.573
# 3   1951  1.948  0.297  0.3940  1.550  0.564
# 4   1952  2.265  0.310  0.3559  1.802  0.574
# 5   1953  2.731  0.322  0.3593  1.926  0.711
# 6   1954  3.025  0.335  0.4025  1.964  0.776
# 7   1955  3.562  0.350  0.3961  2.116  0.827
# 8   1956  3.979  0.361  0.3822  2.435  0.800
# 9   1957  4.420  0.379  0.3045  2.707  0.921
# 10  1958  4.563  0.391  0.3284  2.706  1.067
# 11  1959  5.385  0.426  0.3856  2.846  1.083

# %%
data = pd.read_excel("C:/work/airline.xls" , sheet_name = "a1")

# %%
print(data)
# Out:
#     YEAR      Y      W       R      L      K
# 0   1948  1.214  0.243  0.1454  1.415  0.612
# 1   1949  1.354  0.260  0.2181  1.384  0.559
# 2   1950  1.569  0.278  0.3157  1.388  0.573
# 3   1951  1.948  0.297  0.3940  1.550  0.564
# 4   1952  2.265  0.310  0.3559  1.802  0.574
# 5   1953  2.731  0.322  0.3593  1.926  0.711
# 6   1954  3.025  0.335  0.4025  1.964  0.776
# 7   1955  3.562  0.350  0.3961  2.116  0.827
# 8   1956  3.979  0.361  0.3822  2.435  0.800
# 9   1957  4.420  0.379  0.3045  2.707  0.921
# 10  1958  4.563  0.391  0.3284  2.706  1.067
# 11  1959  5.385  0.426  0.3856  2.846  1.083

# %%
data1 = pd.read_excel("C:/work/airline.xls" , sheet_name = "Shee3", names=['a','b','c','d','e','f'])

# %%
print(data1)
# Out:
#        a       b      c       d      e      f
# 0   1961   5.465  0.460  0.3079  3.122  1.736
# 1   1962   5.825  0.485  0.3783  3.184  1.926
# 2   1963   6.876  0.506  0.4180  3.263  2.041
# 3   1964   7.823  0.538  0.5163  3.412  1.997
# 4   1965   9.120  0.564  0.5879  3.623  2.257
# 5   1966  10.512  0.586  0.5369  4.074  2.742
# 6   1967  13.020  0.622  0.4443  4.710  3.564
# 7   1968  15.261  0.666  0.3052  5.217  4.767
# 8   1969  16.313  0.731  0.2332  5.569  6.511
# 9   1970  16.002  0.831  0.1883  5.495  7.627
# 10  1971  15.876  0.906  0.2023  5.334  8.673

# %%
data1.to_csv('test1.csv', index=False)

# %%
data1.to_excel("test2.xlsx")

# %% [markdown]
# > ModuleNotFoundError: No module named 'openpyxl'== To solve this error, you need to install openpyxl module. In this tutorial, we will use pip to install openpyxl module. Run the following command, to install openpyxl.
#
# pip install openpyxl

# %% [markdown]
# Output exceeds the size limit. Open the full output data in a text editor
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [193], line 1
# ----> 1 data1.to_excel("test2.xlsx")
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:2374, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2361 from pandas.io.formats.excel import ExcelFormatter
#    2363 formatter = ExcelFormatter(
#    2364     df,
#    2365     na_rep=na_rep,
#    (...)
#    2372     inf_rep=inf_rep,
#    2373 )
# -> 2374 formatter.write(
#    2375     excel_writer,
# ...
#    (...)
#      65         engine_kwargs=engine_kwargs,
#      66     )
#
# ModuleNotFoundError: No module named 'openpyxl'

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data1.to_excel("test2.xlsx")

# %%
data1.head()
# Out:
#       a      b      c       d      e      f
# 0  1961  5.465  0.460  0.3079  3.122  1.736
# 1  1962  5.825  0.485  0.3783  3.184  1.926
# 2  1963  6.876  0.506  0.4180  3.263  2.041
# 3  1964  7.823  0.538  0.5163  3.412  1.997
# 4  1965  9.120  0.564  0.5879  3.623  2.257

# %%
data1.tail()
# Out:
#        a       b      c       d      e      f
# 6   1967  13.020  0.622  0.4443  4.710  3.564
# 7   1968  15.261  0.666  0.3052  5.217  4.767
# 8   1969  16.313  0.731  0.2332  5.569  6.511
# 9   1970  16.002  0.831  0.1883  5.495  7.627
# 10  1971  15.876  0.906  0.2023  5.334  8.673

# %%
type(data1)
# Out:
# pandas.core.frame.DataFrame

# %%
data1.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f'], dtype='object')

# %%
list(data1.columns)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
data1[['b','c']]
# Out:
#          b      c
# 0    5.465  0.460
# 1    5.825  0.485
# 2    6.876  0.506
# 3    7.823  0.538
# 4    9.120  0.564
# 5   10.512  0.586
# 6   13.020  0.622
# 7   15.261  0.666
# 8   16.313  0.731
# 9   16.002  0.831
# 10  15.876  0.906

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %% [markdown]
# >ImportError: lxml not found, please install it
#     pip3 install lxml

# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
data2 = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
type(data2)
# Out:
# list

# %%
len(data2)
# Out:
# 1

# %%
data2[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
data2[0].to_csv("players.csv")

# %% [markdown]
# # 28th Jan Day-2 Pandas

# %%
import pandas as pd

# %%
pd.read_csv("C:/work/addresses.csv")
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
data = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
data.head() # data.head()->using head we can see first five record of data set
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail(3) #tail command give you last 5 record of data set,here we put 3 so it showing last 3
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data.dtypes # object is eqivalent to string
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.info() # object in case of pandas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# > you will be able to see passenger id ,survived and many more ,count of total 891000 record, in column age there are sum record are missing,we can do fill operation.

# %%
data[["Name","Sex", "Ticket"]].describe() # filter out datatype object
# Out:
#                            Name   Sex  Ticket
# count                       891   891     891
# unique                      891     2     681
# top     Braund, Mr. Owen Harris  male  347082
# freq                          1   577       7

# %% [markdown]
# #### filter out datatype

# %%
type(data.dtypes) #you can get
# Out:
# pandas.core.series.Series

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data['Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
data.dtypes == "object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
data.dtypes[data.dtypes == "object"].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
data[data.dtypes[data.dtypes == "object"].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
data[data.dtypes[data.dtypes == "object"].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.head(0)
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
data[data['Survived']==0]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
data[(data['Survived'] == 0) & (data['Sex'] == 'male')].count()
# Out:
# PassengerId    468
# Survived       468
# Pclass         468
# Name           468
# Sex            468
# Age            360
# SibSp          468
# Parch          468
# Ticket         468
# Fare           468
# Cabin           62
# Embarked       468
# dtype: int64

# %%
len(data[(data['Survived'] == 0) & (data['Sex'] == 'male')])
# Out:
# 468

# %%
len(data[(data['Survived'] == 0) & (data['Sex'] == 'female')])
# Out:
# 81

# %%
data['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
len(data[data['Sex'] == 'male'])
# Out:
# 577

# %%
len(data[data['Sex'] == 'female'])
# Out:
# 314

# %%
len(data[(data['Survived'] == 1) & (data['Sex'] == 'male')])
# Out:
# 109

# %%
len(data[(data['Survived'] == 1) & (data['Sex'] == 'female')])
# Out:
# 233

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
max(data['Fare'])
# Out:
# 512.3292

# %%
data[data['Fare'] == max(data['Fare'])][['Name']]
# Out:
#                                    Name
# 258                    Ward, Miss. Anna
# 679  Cardeza, Mr. Thomas Drake Martinez
# 737              Lesurer, Mr. Gustave J

# %%
data[data['Fare'] == max(data['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
data[data['Fare'] == min(data['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
data[data['Pclass'] == max(data['Pclass'])]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
data[data['Pclass'] == min(data['Pclass'])]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(data[data['Cabin'].isnull() == False]) #filter operation
# Out:
# 204

# %% [markdown]
# #### LOC and IOC
# ##### LOC
# Access a group of rows and columns by label(s) or a boolean array.
#
# .loc[] is primarily label based, but may also be used with a boolean array.
#
# ##### Allowed inputs are:
#
# * A single label, e.g. 5 or 'a', (note that 5 is interpreted as a label of the index, and never as an integer position along the index).
#
# * A list or array of labels, e.g. ['a', 'b', 'c'].
#
# * A slice object with labels, e.g. 'a':'f'.
#
# > Warning -Note that contrary to usual python slices, both the start and the stop are included
#
# * A boolean array of the same length as the axis being sliced, e.g. [True, False, True].
#
# * An alignable boolean Series. The index of the key will be aligned before masking.
#
# * An alignable Index. The Index of the returned selection will be the input.
#
# * A callable function with one argument (the calling Series or DataFrame) and that returns valid output for indexing (one of the above)

# %% [markdown]
# > https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html  (for pandas)

# %%
data['Name_New'] = data['Puneet']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Puneet'
#
# ...

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data['age_Pclass'] = data['Age'] + data['Pclass']

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data = data.drop(0)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### iloc
# property DataFrame.iloc[source]
# Purely integer-location based indexing for selection by position.
#
# .iloc[] is primarily integer position based (from 0 to length-1 of the axis), but may also be used with a boolean array.
#
# ##### Allowed inputs are:
#
# * An integer, e.g. 5.
#
# * A list or array of integers, e.g. [4, 3, 0].
#
# * A slice object with ints, e.g. 1:7.
#
# * A boolean array.
#
# * A callable function with one argument (the calling Series or DataFrame) and that returns valid output for indexing (one of the above). This is useful in method chains, when you don’t have a reference to the calling object, but would like to base your selection on some value.
#
# * A tuple of row and column indexes. The tuple elements consist of one of the above inputs, e.g. (0, 1).
#
# > .iloc will raise IndexError if a requested indexer is out-of-bounds, except slice indexers which allow out-of-bounds indexing (this conforms with python/numpy slice semantics).

# %%
data.iloc[0]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Name: 1, dtype: object

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q

# %%
data.loc[2:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
# 5                              Moran, Mr. James    male   NaN      0      0
#
#              Ticket     Fare Cabin Embarked
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S
# 5            330877   8.4583   NaN        Q

# %%
data.loc[101:106,['Survived','Pclass']]
# Out:
#      Survived  Pclass
# 101         0       3
# 102         0       1
# 103         0       3
# 104         0       3
# 105         0       3
# 106         1       3

# %%
data.loc[3:4,['Fare','Cabin','Embarked']]
# Out:
#     Fare Cabin Embarked
# 3  53.10  C123        S
# 4   8.05   NaN        S

# %%
data.iloc[3:4,['Fare','Cabin','Embarked']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [188], line 1
# ----> 1 data.iloc[3:4,['Fare','Cabin','Embarked']]
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1563, in _iLocIndexer._getitem_tuple(self, tup)
#    1561 def _getitem_tuple(self, tup: tuple):
# -> 1563     tup = self._validate_tuple_indexer(tup)
#    1564     with suppress(IndexingError):
# ...

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.iloc[[2,5],[9,10,11]]
# Out:
#       Fare Cabin Embarked
# 3  53.1000  C123        S
# 6  51.8625   E46        S

# %%
data.loc[: , ['PassengerId','Pclass']]
# Out:
#      PassengerId  Pclass
# 1              2       1
# 2              3       3
# 3              4       1
# 4              5       3
# 5              6       3
# ..           ...     ...
# 886          887       2
# 887          888       1
# 888          889       3
# 889          890       1
# 890          891       3
#
# [890 rows x 2 columns]

# %%
data.iloc[: , [1,3]]
# Out:
#      Survived                                               Name
# 1           1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1                             Heikkinen, Miss. Laina
# 3           1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0                           Allen, Mr. William Henry
# 5           0                                   Moran, Mr. James
# ..        ...                                                ...
# 886         0                              Montvila, Rev. Juozas
# 887         1                       Graham, Miss. Margaret Edith
# 888         0           Johnston, Miss. Catherine Helen "Carrie"
# 889         1                              Behr, Mr. Karl Howell
# 890         0                                Dooley, Mr. Patrick
#
# [890 rows x 2 columns]

# %%
data.loc[3:5 , ['PassengerId','Survived','Pclass']]
# Out:
#    PassengerId  Survived  Pclass
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3

# %%
data.iloc[[3,5] , [1,2,3]]
# Out:
#    Survived  Pclass                      Name
# 4         0       3  Allen, Mr. William Henry
# 6         0       1   McCarthy, Mr. Timothy J

# %%
data[data['Age'] > 35]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data1 = data.iloc[1:10, 0:5]

# %%
data1
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
# 5                                   Moran, Mr. James    male
# 6                            McCarthy, Mr. Timothy J    male
# 7                     Palsson, Master. Gosta Leonard    male
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female

# %%
data3 = data.iloc[2:6, [2,3,4,5,9,10]]

# %%
data3
# Out:
#    Pclass                                               Name     Sex   Age  \
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                           Allen, Mr. William Henry    male  35.0
#
#       Fare Cabin
# 1  71.2833   C85
# 2   7.9250   NaN
# 3  53.1000  C123
# 4   8.0500   NaN

# %%
data3.set_index('Name',inplace=True)

# %%
data3
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare Cabin
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# Heikkinen, Miss. Laina                               7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123
# Allen, Mr. William Henry                             8.0500   NaN

# %%
data3.dropna()
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
#
#                                                        Fare Cabin
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123

# %% [markdown]
# > AXIS - A DataFrame object has two axes: “axis 0” and “axis 1”. “axis 0” represents rows and “axis 1” represents columns

# %%
data3.dropna(axis=1)
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833
# Heikkinen, Miss. Laina                               7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000
# Allen, Mr. William Henry                             8.0500

# %%
data3.dropna(axis=0)
# Out:
#    Pclass                                               Name     Sex   Age  \
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
#
#       Fare Cabin
# 1  71.2833   C85
# 3  53.1000  C123

# %% [markdown]
# > thresh value- thresh parameter value decides the minimum number of non-NAN values needed in a "ROW" not to drop.

# %%
data3.dropna(axis=1,thresh=1)
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare Cabin
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# Heikkinen, Miss. Laina                               7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123
# Allen, Mr. William Henry                             8.0500   NaN

# %%
data3.dropna(axis=1,thresh=2)
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare Cabin
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# Heikkinen, Miss. Laina                               7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123
# Allen, Mr. William Henry                             8.0500   NaN

# %%
data3.dropna(axis=1,thresh=4)
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833
# Heikkinen, Miss. Laina                               7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000
# Allen, Mr. William Henry                             8.0500

# %%
data3.dropna(axis=0,thresh=4)
# Out:
#                                                     Pclass     Sex   Age  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...       1  female  38.0
# Heikkinen, Miss. Laina                                   3  female  26.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)             1  female  35.0
# Allen, Mr. William Henry                                 3    male  35.0
#
#                                                        Fare Cabin
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  71.2833   C85
# Heikkinen, Miss. Laina                               7.9250   NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)        53.1000  C123
# Allen, Mr. William Henry                             8.0500   NaN

# %%
data3
# Out:
#    Pclass                                               Name     Sex   Age  \
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                           Allen, Mr. William Henry    male  35.0
#
#       Fare Cabin
# 1  71.2833   C85
# 2   7.9250   NaN
# 3  53.1000  C123
# 4   8.0500   NaN

# %%
data3.dropna(axis=0,thresh=4)
# Out:
#    Pclass                                               Name     Sex   Age  \
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                           Allen, Mr. William Henry    male  35.0
#
#       Fare Cabin
# 1  71.2833   C85
# 2   7.9250   NaN
# 3  53.1000  C123
# 4   8.0500   NaN

# %%
data3.fillna('Puneet')
# Out:
#    Pclass                                               Name     Sex   Age  \
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                           Allen, Mr. William Henry    male  35.0
#
#       Fare   Cabin
# 1  71.2833     C85
# 2   7.9250  Puneet
# 3  53.1000    C123
# 4   8.0500  Puneet

# %%
data3.fillna(data3['Age'].mean())
# Out:
#    Pclass                                               Name     Sex   Age  \
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                           Allen, Mr. William Henry    male  35.0
#
#       Fare Cabin
# 1  71.2833   C85
# 2   7.9250  33.5
# 3  53.1000  C123
# 4   8.0500  33.5

# %%
data3.groupby('Sex').count()
# Out:
#         Pclass  Name  Age  Fare  Cabin
# Sex
# female       3     3    3     3      2
# male         1     1    1     1      0

# %%
data3.groupby('Sex').mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9448\3168709885.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data3.groupby('Sex').mean()
#           Pclass   Age       Fare
# Sex
# female  1.666667  33.0  44.102767
# male    3.000000  35.0   8.050000

# %%
data3.groupby('Sex').sum()['Fare']
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9448\1581230297.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data3.groupby('Sex').sum()['Fare']
# Sex
# female    132.3083
# male        8.0500
# Name: Fare, dtype: float64

# %%
data4 = data.iloc[1:5,0:5]

# %%
data4
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
pd.concat([data3,data4])
# Out:
#    Pclass                                               Name     Sex   Age  \
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                           Allen, Mr. William Henry    male  35.0
# 5       3                                   Moran, Mr. James    male   NaN
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   NaN
# 2       3                             Heikkinen, Miss. Laina  female   NaN
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   NaN
# 4       3                           Allen, Mr. William Henry    male   NaN
#
#       Fare Cabin       new      new1  PassengerId  Survived
# 2   7.9250   NaN  1.000000  1.000000          NaN       NaN
# 3  53.1000  C123  0.333333  0.333333          NaN       NaN
# 4   8.0500   NaN  1.000000  1.000000          NaN       NaN
# ...

# %%
pd.concat([data3,data4],axis=0)
# Out:
#    Pclass                                               Name     Sex   Age  \
# 2       3                             Heikkinen, Miss. Laina  female  26.0
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                           Allen, Mr. William Henry    male  35.0
# 5       3                                   Moran, Mr. James    male   NaN
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   NaN
# 2       3                             Heikkinen, Miss. Laina  female   NaN
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   NaN
# 4       3                           Allen, Mr. William Henry    male   NaN
#
#       Fare Cabin       new      new1  PassengerId  Survived
# 2   7.9250   NaN  1.000000  1.000000          NaN       NaN
# 3  53.1000  C123  0.333333  0.333333          NaN       NaN
# 4   8.0500   NaN  1.000000  1.000000          NaN       NaN
# ...

# %%
data3
# Out:
#    Pclass                                          Name     Sex   Age  \
# 2       3                        Heikkinen, Miss. Laina  female  26.0
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                      Allen, Mr. William Henry    male  35.0
# 5       3                              Moran, Mr. James    male   NaN
#
#       Fare Cabin       new      new1
# 2   7.9250   NaN  1.000000  1.000000
# 3  53.1000  C123  0.333333  0.333333
# 4   8.0500   NaN  1.000000  1.000000
# 5   8.4583   NaN  1.000000  1.000000

# %%
data3['new'] = data3['Pclass'].apply(lambda x : x/3)

# %%
data3
# Out:
#    Pclass                                          Name     Sex   Age  \
# 2       3                        Heikkinen, Miss. Laina  female  26.0
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                      Allen, Mr. William Henry    male  35.0
# 5       3                              Moran, Mr. James    male   NaN
#
#       Fare Cabin       new
# 2   7.9250   NaN  1.000000
# 3  53.1000  C123  0.333333
# 4   8.0500   NaN  1.000000
# 5   8.4583   NaN  1.000000

# %%
def fun1(x):
    return x/3

# %%
data3['new1'] = data3['Pclass'].apply(fun1)

# %%
data3
# Out:
#    Pclass                                          Name     Sex   Age  \
# 2       3                        Heikkinen, Miss. Laina  female  26.0
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                      Allen, Mr. William Henry    male  35.0
# 5       3                              Moran, Mr. James    male   NaN
#
#       Fare Cabin       new      new1
# 2   7.9250   NaN  1.000000  1.000000
# 3  53.1000  C123  0.333333  0.333333
# 4   8.0500   NaN  1.000000  1.000000
# 5   8.4583   NaN  1.000000  1.000000

# %%
data4['len_name'] = data4['Name'].apply(len)

# %%
data4
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
import math
def cust1(x):    #custom function
    if x <3 :
        return x
    else :
        return math.log10(x)

# %%
data4['PassengerId_filter'] = data4['PassengerId'].apply(cust1)

# %%
data4
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#    PassengerId_filter
# 1            2.000000
# 2            0.477121
# 3            0.602060
# 4            0.698970

# %%
def test2(x):
    if x == 'female':
        return 1
    else :
        return 0

# %%
data4['Sex'] = data4['Sex'].apply(test2)

# %%
data4
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex  PassengerId_filter
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1            2.000000
# 2                             Heikkinen, Miss. Laina    1            0.477121
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1            0.602060
# 4                           Allen, Mr. William Henry    0            0.698970

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# 0 - 100 = 'A'
# 100-199 = 'B'
# 200+ ='C'

# %%
def test3(x):
    if X <= 100 :
        return "A"
    elif x >100 and x<200:
        return "B"
    else :
        return "C"

# %% [markdown]
# def test3(x):
#     if x <= 100 :
#         return "A"
#     elif x >100 and x<200:
#         return "B"
#     else :
#         return "C"

# %%
def test3(x):
    if x <= 100 :
        return "A"
    elif x >100 and x<200:
        return "B"
    else :
        return "C"

# %%
data['Fare_group'] = data['Fare'].apply(test3)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
